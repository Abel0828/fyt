# %%
import numpy as np
import pandas as pd
import math

import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as tqdm
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('../data/Jinshenlu2.txt',sep='\t',
              error_bad_lines=False, low_memory=False,
              usecols=['xuhao', 'year', 'diqu', 'jigou_1', 'jigou_2', 'jigou_3',
                       'core_guanzhi', 'pinji_detailed', 'pinji_numeric', 'unique_id', 'fangkeben_only', 'qiren'])

# %%
df.dropna(subset=['unique_id'], inplace=True)
df=df[(df['xuhao']<20000) & (df['qiren']=='民人') & (df['fangkeben_only']<0.5)]
df.describe(include='all')
# Out:
#                xuhao          year     diqu  jigou_1  jigou_2 jigou_3  \
# count   1.969975e+06  1.969975e+06  1969950  1959138  1598372   59582
# unique           NaN           NaN       33     1101     3079     486
# top              NaN           NaN       京師    翰林院衙門     額外司員    至聖廟官
# freq             NaN           NaN   294981    44263    94288   12583
# mean    8.325592e+03  1.873890e+03      NaN      NaN      NaN     NaN
# std     3.752866e+03  3.336632e+01      NaN      NaN      NaN     NaN
# min     2.000000e+00  1.760750e+03      NaN      NaN      NaN     NaN
# 25%     5.721000e+03  1.858750e+03      NaN      NaN      NaN     NaN
# 50%     8.554000e+03  1.883000e+03      NaN      NaN      NaN     NaN
# 75%     1.129400e+04  1.898000e+03      NaN      NaN      NaN     NaN
# max     1.974800e+04  1.912000e+03      NaN      NaN      NaN     NaN
#
#        core_guanzhi pinji_detailed  pinji_numeric     unique_id  \
# count       1919929        1829174   1.854298e+06  1.969975e+06
# unique         6160             30            NaN           NaN
# top              訓導            正八品            NaN           NaN
# freq         292749         359893            NaN           NaN
# mean            NaN            NaN   6.241923e+00  1.866318e+11
# std             NaN            NaN   2.839672e+00  3.304830e+09
# min             NaN            NaN   0.000000e+00  1.760400e+11
# 25%             NaN            NaN   5.000000e+00  1.851407e+11
# 50%             NaN            NaN   7.000000e+00  1.874114e+11
# 75%             NaN            NaN   8.000000e+00  1.890212e+11
# max             NaN            NaN   9.000000e+00  1.912119e+11
#
#         fangkeben_only    qiren
# count        1969975.0  1969975
# unique             NaN        1
# top                NaN       民人
# freq               NaN  1969975
# mean               0.0      NaN
# std                0.0      NaN
# min                0.0      NaN
# 25%                0.0      NaN
# 50%                0.0      NaN
# 75%                0.0      NaN
# max                0.0      NaN

# %%
df[(df['pinji_numeric'].notnull()) & (df['pinji_detailed'].isnull())]
# Out:
#            xuhao     year diqu jigou_1 jigou_2 jigou_3  \
# 182921    2256.0  1797.75   京師   都察院衙門     NaN     NaN
# 182991    5674.0  1788.00   江西   布政司衙門     NaN     NaN
# 183465   12849.0  1788.00   貴州   布政司衙門     NaN     NaN
# 183686     622.0  1777.50   京師   詹事府衙門     司經局     NaN
# 183688    2203.0  1788.00   京師   都察院衙門     NaN     NaN
# 183733    2236.0  1796.00   京師   都察院衙門     NaN     NaN
# 184244     587.0  1765.00   京師   詹事府衙門     NaN     NaN
# 184566    5359.0  1797.75   安徽   布政司衙門     NaN     NaN
# 184567    4828.0  1798.50   安徽   布政司衙門     NaN     NaN
# 184568    5372.0  1798.75   安徽   布政司衙門     NaN     NaN
# 185126     912.0  1761.50   京師      戶部     貴州司     NaN
# 185296    3535.0  1765.75   直隸     順天府      通州     NaN
# 185414     880.0  1761.50   京師      戶部     廣東司     NaN
# 189383    1863.0  1760.75   京師      工部     營膳司     NaN
# 191006    4379.0  1765.75   江南     NaN     NaN     NaN
# 191007   10859.0  1777.50   廣東   布政司衙門     NaN     NaN
# 192642    2680.0  1760.75   京師     太常寺     NaN     NaN
# 192643    2724.0  1761.50   京師     太常寺     典簿廳     NaN
# 192714    2706.0  1760.75   京師     順天府     宛平縣     NaN
# 192929    1102.0  1761.50   京師      戶部     NaN     NaN
# 192932    2754.0  1760.75   京師     光祿寺     大官署     NaN
# 192933    2798.0  1761.50   京師     光祿寺     太官署     NaN
# 192945    2758.0  1760.75   京師     光祿寺     珍饈署     NaN
# 192966    2762.0  1760.75   京師     光祿寺     良醖署     NaN
# 192967    2806.0  1761.50   京師     光祿寺     良醢署     NaN
# 192983    2766.0  1760.75   京師     光祿寺     掌醢署     NaN
# 195792    3602.0  1761.50   直隸     順天府     NaN     NaN
# 195797    3604.0  1761.50   直隸     順天府     NaN     NaN
# 195839    3610.0  1760.75   直隸     順天府     固安縣     NaN
# 195840    3621.0  1761.50   直隸     順天府     固安縣     NaN
# ...          ...      ...  ...     ...     ...     ...
# 2894833  17726.0  1911.75   廣東     提學司     普通科     NaN
# 2894834  17624.0  1912.00   廣東     提學司     普通科     NaN
# 2894889  17758.0  1911.75   廣東     提法司     巡警道     總務科
# 2894890  17656.0  1912.00   廣東     提法司     巡警道     總務科
# 2894899  17763.0  1911.75   廣東     提法司     巡警道     總務科
# 2894900  17661.0  1912.00   廣東     提法司     巡警道     總務科
# 2894921  17774.0  1911.75   廣東     提法司     巡警道     行政科
# 2894922  17672.0  1912.00   廣東     提法司     巡警道     行政科
# 2894983  18106.0  1911.75   廣東     潮州府     NaN     NaN
# 2894984  18004.0  1912.00   廣東     潮州府     NaN     NaN
# 2895237  18462.0  1911.75   廣西     提學司     專門科     NaN
# 2895238  18359.0  1912.00   廣西     提學司     專門科     NaN
# 2895255  18471.0  1911.75   廣西     提學司     圖書館     NaN
# 2895256  18368.0  1912.00   廣西     提學司     圖書館     NaN
# 2895289  18491.0  1911.75   廣西     提法司     巡警道     總務科
# 2895290  18388.0  1912.00   廣西     提法司     巡警道     總務科
# 2895387  18541.0  1911.75   廣西     提法司     勸業道     郵傳科
# 2895388  18438.0  1912.00   廣西     提法司     勸業道     郵傳科
# 2895537  18974.0  1911.75   雲南     提學司     普通科     NaN
# 2895538  18870.0  1912.00   雲南     提學司     普通科     NaN
# 2895565  18988.0  1911.75   雲南     提學司     會計科     NaN
# 2895566  18884.0  1912.00   雲南     提學司     會計科     NaN
# 2895581  18998.0  1911.75   雲南     提法司     巡警道     NaN
# 2895582  18894.0  1912.00   雲南     提法司     巡警道     NaN
# 2895790  19476.0  1911.75   貴州     提法司     巡警道     總務科
# 2895791  19372.0  1912.00   貴州     提法司     巡警道     總務科
# 2896124   9756.0  1912.00   直隸     提學司     NaN     NaN
# 2896152  11598.0  1912.00   山東     布政司     NaN     NaN
# 2896154  11601.0  1912.00   山東     提學司     NaN     NaN
# 2896194  16422.0  1912.00   湖南     布政司     NaN     NaN
#
#                      core_guanzhi pinji_detailed  pinji_numeric     unique_id  \
# 182921                        都禦史            NaN            1.0  1.760400e+11
# 182991                         政使            NaN            2.0  1.760400e+11
# 183465                         政使            NaN            2.0  1.760400e+11
# 183686              文淵閣校理司經局洗馬掌局事            NaN            6.0  1.760400e+11
# 183688                         學政            NaN            3.0  1.760400e+11
# 183733                        都禦史            NaN            1.0  1.760400e+11
# 184244             日講官起居註司經局洗馬掌局事            NaN            6.0  1.760401e+11
# 184566                         政使            NaN            2.0  1.760401e+11
# 184567                         政使            NaN            2.0  1.760401e+11
# 184568                         政使            NaN            2.0  1.760401e+11
# 185126                        NaN            NaN            5.0  1.760401e+11
# 185296                   欽命總理七省漕務            NaN            5.0  1.760401e+11
# 185414                特用郎中加太僕寺少卿銜            NaN            4.0  1.760401e+11
# 189383                   特用郎中????            NaN            5.0  1.760402e+11
# 191006   分管漕務督理江安江徽寧池太盧鳯揚等處地方?府粮道            NaN            4.0  1.760402e+11
# 191007                         政使            NaN            2.0  1.760402e+11
# 192642                         署正            NaN            6.0  1.760403e+11
# 192643                         署正            NaN            6.0  1.760403e+11
# 192714                       州同??            NaN            6.0  1.760403e+11
# 192929                         署正            NaN            6.0  1.760403e+11
# 192932                         署正            NaN            6.0  1.760403e+11
# 192933                         署正            NaN            6.0  1.760403e+11
# 192945                         署正            NaN            6.0  1.760403e+11
# 192966                         署正            NaN            6.0  1.760403e+11
# 192967                         署正            NaN            6.0  1.760403e+11
# 192983                         署正            NaN            6.0  1.760403e+11
# 195792                       南路捕盜            NaN            5.0  1.760404e+11
# 195797                       北路捕盜            NaN            5.0  1.760404e+11
# 195839                   北運河通判???            NaN            6.0  1.760404e+11
# 195840                   北運河通判???            NaN            6.0  1.760404e+11
# ...                           ...            ...            ...           ...
# 2894833                    科員通判職銜            NaN            6.0  1.911418e+11
# 2894834                    科員通判職銜            NaN            6.0  1.911418e+11
# 2894889                    科員州同職銜            NaN            6.0  1.911418e+11
# 2894890                    科員州同職銜            NaN            6.0  1.911418e+11
# 2894899                    科員州同職銜            NaN            6.0  1.911418e+11
# 2894900                    科員州同職銜            NaN            6.0  1.911418e+11
# 2894921                    科員州同職銜            NaN            6.0  1.911418e+11
# 2894922                    科員州同職銜            NaN            6.0  1.911418e+11
# 2894983                       NaN            NaN            5.0  1.911418e+11
# 2894984                       NaN            NaN            5.0  1.911418e+11
# 2895237                   副科長通判職銜            NaN            6.0  1.911418e+11
# 2895238                   副科長通判職銜            NaN            6.0  1.911418e+11
# 2895255                   副科長通判職銜            NaN            6.0  1.911418e+11
# 2895256                   副科長通判職銜            NaN            6.0  1.911418e+11
# 2895289                    科員同知職銜            NaN            5.0  1.911418e+11
# 2895290                    科員同知職銜            NaN            5.0  1.911418e+11
# 2895387                     科員州同銜            NaN            6.0  1.911419e+11
# 2895388                     科員州同銜            NaN            6.0  1.911419e+11
# 2895537                    科長郎中職銜            NaN            5.0  1.911419e+11
# 2895538                    科長郎中職銜            NaN            5.0  1.911419e+11
# 2895565                   副科長通判職銜            NaN            6.0  1.911419e+11
# 2895566                   副科長通判職銜            NaN            6.0  1.911419e+11
# 2895581                    科長州判職銜            NaN            7.0  1.911419e+11
# 2895582                    科長州判職銜            NaN            7.0  1.911419e+11
# 2895790                    科員同知職銜            NaN            5.0  1.911419e+11
# 2895791                    科員同知職銜            NaN            5.0  1.911419e+11
# 2896124               署任直隸提學使司提學使            NaN            3.0  1.912110e+11
# 2896152                        政使            NaN            2.0  1.912112e+11
# 2896154                署山東提學使司提學使            NaN            3.0  1.912112e+11
# 2896194                        政使            NaN            2.0  1.912116e+11
#
#          fangkeben_only qiren
# 182921              0.0    民人
# 182991              0.0    民人
# 183465              0.0    民人
# 183686              0.0    民人
# 183688              0.0    民人
# 183733              0.0    民人
# 184244              0.0    民人
# 184566              0.0    民人
# 184567              0.0    民人
# 184568              0.0    民人
# 185126              0.0    民人
# 185296              0.0    民人
# 185414              0.0    民人
# 189383              0.0    民人
# 191006              0.0    民人
# 191007              0.0    民人
# 192642              0.0    民人
# 192643              0.0    民人
# 192714              0.0    民人
# 192929              0.0    民人
# 192932              0.0    民人
# 192933              0.0    民人
# 192945              0.0    民人
# 192966              0.0    民人
# 192967              0.0    民人
# 192983              0.0    民人
# 195792              0.0    民人
# 195797              0.0    民人
# 195839              0.0    民人
# 195840              0.0    民人
# ...                 ...   ...
# 2894833             0.0    民人
# 2894834             0.0    民人
# 2894889             0.0    民人
# 2894890             0.0    民人
# 2894899             0.0    民人
# 2894900             0.0    民人
# 2894921             0.0    民人
# 2894922             0.0    民人
# 2894983             0.0    民人
# 2894984             0.0    民人
# 2895237             0.0    民人
# 2895238             0.0    民人
# 2895255             0.0    民人
# 2895256             0.0    民人
# 2895289             0.0    民人
# 2895290             0.0    民人
# 2895387             0.0    民人
# 2895388             0.0    民人
# 2895537             0.0    民人
# 2895538             0.0    民人
# 2895565             0.0    民人
# 2895566             0.0    民人
# 2895581             0.0    民人
# 2895582             0.0    民人
# 2895790             0.0    民人
# 2895791             0.0    民人
# 2896124             0.0    民人
# 2896152             0.0    民人
# 2896154             0.0    民人
# 2896194             0.0    民人
#
# [25128 rows x 12 columns]

# %%
guanzhi_pj=df[['core_guanzhi','pinji_detailed']].copy(deep=True).set_index('core_guanzhi').to_dict('index')

# %%
len(guanzhi_pj)
# Out:
# 6161

# %% [markdown]
# # Preprocessing Flow:
# 1. remove entries without unique_id identifier
# 2. remove entries of millitary people (xuhao>=20000)
# 3. remove entries without pinji_detailed (pinji_numeric is not reliable at all)
#
# ## problems:
#     1. no 旗人 flag?
#     2. entries without 'pinji_numeric' need to be fixed
#     3. 1986254	5491	0	1909.50	京師	陵寢官員	NaN	NaN	昌陵主事	主事	鄭路平	6.0	1.878205e+11
#     225816	3477	0	1761.50	京師	盛京	NaN	NaN	銀庫員外郎	員外郎	從物品	5.0	1.760402e+11
#
#     4. fangkeben_only may affect a little bit
#     5. df[df['unique_id']==176040043800].sort_values(by=['year']) very weird?

# %%
# created by you xiu de bang bang :P

df=pd.read_csv('../data/Jinshenlu2.txt',sep='\t',
              error_bad_lines=False, low_memory=False,
              usecols=['xuhao', 'year', 'diqu', 'jigou_1', 'jigou_2', 'jigou_3',
                       'core_guanzhi', 'pinji_detailed', 'pinji_numeric', 'unique_id', 'fangkeben_only', 'qiren'])
df.dropna(subset=['unique_id'], inplace=True) # drop unusable entries that don't have unique_id
df=df[(df['xuhao']<20000) & (df['qiren']=='民人') & (df['fangkeben_only']<0.5)] # apply filteration

# the following snippet tries best to recover around 2% of the data in pinji_detailed
dic=dict(zip(['一', '二','三','四','五', '六','七','八','九'], np.arange(1,10)))
guanzhi_pj=df[['core_guanzhi','pinji_detailed']].copy(deep=True).set_index('core_guanzhi').to_dict('index') #convert to dict for quick lookup
def str2float(x):
    s=x[0]
    if pd.isnull(s):
        n=x[1]
        gz=x[2]
        global guanzhi_pj
        pj=guanzhi_pj.get(gz)
        found=False
        if pj:
            if pd.notnull(pj['pinji_detailed']):
                s=pj['pinji_detailed']
                found=True
        if not found:
            if n:
                if n==0.0:
                    return 10.0
                return n
            else:
                return np.nan
    if s in ['不入流', '未入流']:
        return 10.0
    if s=='從一品(應為正四品)':
        return 4.0
    if s=='從物品':
        return 5.5
    if s=='鄭路平':
        return 6.0
    global dic
    base = dic[s[-2]]
    base+=0.5*('從' in s)
    return float(base)
df['pinji_detailed_numeric']=df[['pinji_detailed', 'pinji_numeric', 'core_guanzhi']].apply(str2float, axis=1)
df.drop(['xuhao', 'pinji_detailed', 'pinji_numeric', 'fangkeben_only', 'qiren'], axis=1, inplace=True)
df.dropna(subset=['pinji_detailed_numeric'], inplace=True)
df.describe(include='all')

# %%
df.describe(include='all')
# Out:
#                 year     diqu  jigou_1  jigou_2 jigou_3 core_guanzhi  \
# count   1.858742e+06  1858719  1848636  1534557   46899      1819514
# unique           NaN       33      886     2918     377         4021
# top              NaN       京師    翰林院衙門     額外司員    至聖廟官           訓導
# freq             NaN   254635    43817    93415    8166       292749
# mean    1.873551e+03      NaN      NaN      NaN     NaN          NaN
# std     3.339575e+01      NaN      NaN      NaN     NaN          NaN
# min     1.760750e+03      NaN      NaN      NaN     NaN          NaN
# 25%     1.858750e+03      NaN      NaN      NaN     NaN          NaN
# 50%     1.882750e+03      NaN      NaN      NaN     NaN          NaN
# 75%     1.897750e+03      NaN      NaN      NaN     NaN          NaN
# max     1.912000e+03      NaN      NaN      NaN     NaN          NaN
#
#            unique_id  pinji_detailed_numeric
# count   1.858742e+06            1.858742e+06
# unique           NaN                     NaN
# top              NaN                     NaN
# freq             NaN                     NaN
# mean    1.865949e+11            7.773186e+00
# std     3.302259e+09            1.712638e+00
# min     1.760400e+11            1.000000e+00
# 25%     1.851404e+11            7.000000e+00
# 50%     1.873412e+11            8.000000e+00
# 75%     1.890100e+11            9.000000e+00
# max     1.912119e+11            1.000000e+01

# %%
def plot_distri(arr, name):
    long_flag=False
    if len(arr.shape)==1:
        print('number of unique {}'.format(name), arr.unique().shape[0])
    else:
        
        print('number of unique {}'.format(name), arr.groupby(list(arr.columns)).ngroups)
        long_flag=True
    item_count={}
    for item in arr.values:

        if long_flag:
            it = tuple(item)
        else: 
            it=item
        
        if it not in item_count:
            item_count[it]=1
        else:
            item_count[it]+=1
    sorted_two_tuples=sorted(list(item_count.items()), key=lambda x:-x[1])
    print('Top 20:', sorted_two_tuples[:20])
    print()
    return sorted_two_tuples
#     plt.plot(sorted(item_count.values(),reverse=True))
print('total number of people', df.shape[0], end='\n\n')

plot_distri(df['diqu'], 'diqu （地区）')
plot_distri(df['core_guanzhi'],'guanzhi（官职)')
plot_distri(df['jigou_1'], 'jigou_1 （机构一）')
sorted_two_tuples=plot_distri(df[['jigou_1', 'core_guanzhi']], '(jigou_1, guanzhi) pair （机构一+官职）')
sorted_two_tuples2=plot_distri(df[['jigou_1', 'jigou_2','core_guanzhi']], '(jigou_1, jigou_2, guanzhi) tuple （机构一+机构二+官职）')
sorted_two_tuples3=plot_distri(df[['diqu','jigou_1','jigou_2','jigou_3','core_guanzhi']], 'all')
plt.plot(pd.DataFrame(sorted_two_tuples)[1][:100])
# print(df.groupby(['guanzhi', '', '']))
# Out:
# total number of people 1858742
#
# number of unique diqu （地区） 34
# Top 20: [('京師', 254635), ('直隸', 142402), ('山東', 119162), ('四川', 112147), ('廣東', 105507), ('河南', 102662), ('江西', 100041), ('浙江', 93828), ('山西', 87231), ('湖北', 80257), ('湖南', 76198), ('福建', 75139), ('廣西', 74143), ('雲南', 71818), ('陝西', 71219), ('江南', 70804), ('安徽', 64210), ('貴州', 52302), ('甘肅', 47452), ('江蘇', 35562)]
#
# number of unique guanzhi（官职) 4022
# Top 20: [('訓導', 292749), ('典史', 237516), ('知縣', 219727), ('教諭', 210953), ('巡檢', 167821), ('主事', 90192), ('縣丞', 65903), ('學正', 42604), (nan, 39228), ('教授', 37725), ('知州', 36350), ('同知', 27842), ('經厯', 27047), ('吏目', 24868), ('知府', 24725), ('郎中', 19140), ('主簿', 18998), ('通判', 18701), ('員外郎', 16225), ('千總', 15682)]
#
# number of unique jigou_1 （机构一） 887
# Top 20: [('翰林院衙門', 43817), ('刑部衙門', 33042), ('順天府', 30007), ('戶部衙門', 27375), ('兗州府', 21858), ('總漕部院衙門', 20910), ('廣州府', 20518), ('西安府', 15954), ('開封府', 15651), ('保定府', 15067), ('濟南府', 14976), ('按察司衙門', 14603), ('成都府', 14043), ('工部衙門', 13280), ('正定府', 12962), ('吉安府', 12938), ('長沙府', 12916), ('都察院衙門', 12540), ('吏部衙門', 12201), ('惠州府', 12196)]
#
# number of unique (jigou_1, guanzhi) pair （机构一+官职） 11406
# Top 20: [(('翰林院衙門', nan), 28751), (('刑部衙門', '主事'), 21293), (('戶部衙門', '主事'), 16714), (('總漕部院衙門', '千總'), 15219), (('工部衙門', '主事'), 8735), (('吏部衙門', '主事'), 8082), (('兗州府', '執事官'), 7885), (('度支部衙門', '主事'), 6638), (('廣州府', '巡檢'), 6422), (('兵部衙門', '主事'), 6334), (('禮部衙門', '主事'), 5862), (('都察院衙門', '監察禦史'), 5634), (('法部衙門', '主事'), 5109), (('翰林院衙門', '編修'), 4954), (('太醫院衙門', nan), 4952), (('刑部衙門', '郎中'), 4564), (('順天府', '訓導'), 4307), (('總漕部院衙門', '守備'), 4052), (('刑部衙門', '員外郎'), 4015), (('戶部衙門', '郎中'), 3950)]
#
# number of unique (jigou_1, jigou_2, guanzhi) tuple （机构一+机构二+官职） 19436
# Top 20: [(('刑部衙門', '額外司員', '主事'), 18152), (('翰林院衙門', '翰林院編修', nan), 15876), (('戶部衙門', '額外司員', '主事'), 12569), (('翰林院衙門', '翰林院庶吉士', nan), 9405), (('兗州府', '曲阜縣', '執事官'), 7885), (('工部衙門', '額外司員', '主事'), 7425), (('吏部衙門', '額外司員', '主事'), 6782), (('度支部衙門', '額外司員', '主事'), 6117), (('總漕部院衙門', '江南衛所', '千總'), 5907), (('兵部衙門', '額外司員', '主事'), 5631), (('禮部衙門', '額外司員', '主事'), 5057), (('法部衙門', '額外司員', '主事'), 4683), (('翰林院衙門', '翰林院編修', '編修'), 4534), (('總漕部院衙門', '山東衛所', '千總'), 3953), (('按察司衙門', nan, '司獄'), 3103), (('布政司衙門', nan, '政使'), 2594), (('內閣', '漢票簽中書舍人', '中書'), 2441), (('翰林院衙門', '翰林院庶吉士', '吉士'), 2416), (('陸軍部衙門', '候補主事', '主事'), 2409), (('按察司衙門', nan, '事務'), 2222)]
#
# number of unique all 1405
# Top 20: [(('京師', '刑部衙門', '額外司員', nan, '主事'), 17900), (('京師', '翰林院衙門', '翰林院編修', nan, nan), 15715), (('京師', '戶部衙門', '額外司員', nan, '主事'), 12478), (('京師', '翰林院衙門', '翰林院庶吉士', nan, nan), 8838), (('山東', '兗州府', '曲阜縣', '至聖廟官', '執事官'), 7570), (('京師', '工部衙門', '額外司員', nan, '主事'), 7346), (('京師', '吏部衙門', '額外司員', nan, '主事'), 6715), (('京師', '度支部衙門', '額外司員', '主事', '主事'), 5589), (('京師', '兵部衙門', '額外司員', nan, '主事'), 5491), (('京師', '禮部衙門', '額外司員', nan, '主事'), 5054), (('京師', '法部衙門', '額外司員', nan, '主事'), 4683), (('京師', '翰林院衙門', '翰林院編修', nan, '編修'), 4336), (('京師', '內閣', '漢票簽中書舍人', nan, '中書'), 2441), (('京師', '陸軍部衙門', '候補主事', nan, '主事'), 2409), (('京師', '翰林院衙門', '翰林院檢討', nan, nan), 2128), (('京師', '翰林院衙門', '翰林院庶吉士', nan, '吉士'), 2086), (('京師', '太醫院衙門', '九品吏目', nan, nan), 1669), (('京師', '戶部衙門', '戶部額外司員', nan, '主事'), 1666), (('京師', '太醫院衙門', '八品吏目', nan, nan), 1525), (('山西', '朔平府', nan, nan, '巡檢'), 1473)]

# %%
len(sorted_two_tuples3)
# Out:
# 30076

# %% [markdown]
# # Modeling

# %%
import os
ppry_file=r'../data/pickles/ppry2.pkl'
if os.path.exists(ppry_file):
    print("read existing ppry.")
    ppry=pd.read_pickle(ppry_file)
else:
    print("construct and save new ppry.")
    ppry=df[['unique_id', 'diqu', 'jigou_1', 'jigou_2', 'jigou_3', 'core_guanzhi', 'pinji_detailed_numeric', 'year']] #person_position_rank_year
    open(ppry_file, 'a')
    ppry.to_pickle(ppry_file)
# Out:
# read existing ppry.

# %%
ppry.describe(include='all')
# Out:
#            unique_id     diqu  jigou_1  jigou_2 jigou_3 core_guanzhi  \
# count   1.858742e+06  1858719  1848636  1534557   46899      1819514
# unique           NaN       33      886     2918     377         4021
# top              NaN       京師    翰林院衙門     額外司員    至聖廟官           訓導
# freq             NaN   254635    43817    93415    8166       292749
# mean    1.865949e+11      NaN      NaN      NaN     NaN          NaN
# std     3.302259e+09      NaN      NaN      NaN     NaN          NaN
# min     1.760400e+11      NaN      NaN      NaN     NaN          NaN
# 25%     1.851404e+11      NaN      NaN      NaN     NaN          NaN
# 50%     1.873412e+11      NaN      NaN      NaN     NaN          NaN
# 75%     1.890100e+11      NaN      NaN      NaN     NaN          NaN
# max     1.912119e+11      NaN      NaN      NaN     NaN          NaN
#
#         pinji_detailed_numeric          year
# count             1.858742e+06  1.858742e+06
# unique                     NaN           NaN
# top                        NaN           NaN
# freq                       NaN           NaN
# mean              7.773186e+00  1.873551e+03
# std               1.712638e+00  3.339575e+01
# min               1.000000e+00  1.760750e+03
# 25%               7.000000e+00  1.858750e+03
# 50%               8.000000e+00  1.882750e+03
# 75%               9.000000e+00  1.897750e+03
# max               1.000000e+01  1.912000e+03

# %% [markdown]
# ## temporarily remove nan in jigou_1 and guanzhi

# %% [markdown]
# 1. index all the positions

# %%
def combine(x):
    s=[]
    for item in x:
        if pd.notnull(item):
            s.append(item)
        else:
            s.append('不详')
    return '_'.join(s)
def combine2(row):
    x=[row['diqu'], row['jigou_1'], row['jigou_2'], row['jigou_3'], row['core_guanzhi']]
    s=[]
    for item in x:
        if pd.notnull(item):
            s.append(item)
        else:
            s.append('不详')
    return '_'.join(s)
combine(ppry[['diqu','jigou_1','jigou_2','jigou_3','core_guanzhi']].values[1])
# Out:
# '京師_宗人府_不详_不详_府丞'

# %%
pos = ppry[['diqu','jigou_1','jigou_2','jigou_3','core_guanzhi']].apply(combine, axis=1).unique()

# %%
print(len(pos))
print(pos[:3])
index_table={position: idx for idx, position in enumerate(pos)}
# Out:
# 30076
# ['京師_宗人府_不详_不详_府丞' '京師_宗人府衙門_不详_不详_府丞' '京師_宗人府_經歷司_不详_主事']

# %% [markdown]
# 1. construct A:
# 1) sum t for each edge -- T
# 2) count the # of each edge -- N
# 3) from N construct P -- P
# 4) use T, N, P to construct A -- A

# %%
N = {} # count the number of each edge
T = {} # sum the total time of each edge
for id_, subtable in tqdm(ppry.groupby('unique_id')):
    if subtable.shape[0] == 1:
        continue
    first = True
    pre_pos = None
    cur_pos = None
    pre_year = None
    cur_year = None
    for index, row in subtable.sort_values('year').iterrows():
        if first:
            first = False
            pre_pos = combine2(row)
            pre_year= index
            continue
        else:
            cur_pos = combine2(row)
            flow = (index_table[pre_pos], index_table[cur_pos])
            if flow[0] in N:
                count=N[flow[0]].get(flow[1])
                N[flow[0]][flow[1]] = count+1 if count else 1
                total_time=N[flow[0]].get(flow[1])
                T[flow[0]][flow[1]] = total_time + index - pre_year if total_time else index - pre_year          
            else:
                N[flow[0]]={flow[1]: 1}
                T[flow[0]]={flow[1]: index - pre_year}
            
            pre_pos = cur_pos
            pre_year = index
# Out:
# 100%|█████████████████████████████████████████████████████████| 214719/214719 [08:20<00:00, 428.83it/s]

# %%
print(len(T))
print(len(N))
# Out:
# 27327
# 27327

# %%
P={}
for pos1, row in tqdm(N.items()):
    s=sum(row.values())
    P[pos1]={}
    for pos2, count in row.items():
        P[pos1][pos2]=count/s
# Out:
# 100%|████████████████████████████████████████████████████████| 27327/27327 [00:00<00:00, 217264.64it/s]

# %%
alpha=0.8
A={}
for pos1, row in tqdm(P.items()):
    A[pos1]={}
    for pos2, p in row.items():
        A[pos1][pos2]=(alpha**(T[pos1][pos2]/N[pos1][pos2]))*p
# Out:
# 100%|████████████████████████████████████████████████████████| 27327/27327 [00:00<00:00, 119980.89it/s]

# %%
import numpy as np
mat_A=np.zeros((len(pos), len(pos)),dtype=np.float32)
for pos1, row in A.items():
    for pos2, a in row.items():
        mat_A[pos1, pos2]=a
print(mat_A.shape)
# Out:
# (30076, 30076)

# %%
pinji_iv={1: 16000, 1.5: 14500, 2: 13000, 2.5: 9500, 3: 6000, 3.5: 4850, 
 4: 3700, 4.5: 3050, 5: 2400, 5.5: 1825, 6: 1250, 6.5: 1225, 7:1200, 7.5:1000, 8: 100, 8.5: 90, 9: 80, 9.5:70, 10: 60}
print(len(pinji_iv))
# Out:
# 19

# %% [markdown]
# assign intrinsic values according to: http://xh.5156edu.com/page/z8603m8110j19936.html

# %%
c=np.zeros(len(pos))
for idx, row in tqdm(ppry[['diqu','jigou_1','jigou_2','jigou_3','core_guanzhi', 'pinji_detailed_numeric']].iterrows()):
    c[index_table[combine2(row)]]=pinji_iv[row['pinji_detailed_numeric']] # c is going to be the intrinsic value vector
print(c[:10])
# Out:
# 1858742it [05:36, 5518.85it/s]
# [ 6000.  6000.  1250.  2400.  3700. 16000. 16000. 16000. 14500. 16000.]

# %% [markdown]
# 一品 180两 180斛 16000两（总督） 290万
# 二品 155两 155斛 13000两（巡抚） 236万
# 三品 130两 130斛 6000两（按察史） 112万
# 四品 105两 105斛 3700两（道员） 70万
# 五品 80两 80斛 2400两（从四品知府） 46万
# 六品 60两 60斛 1250两（从五品知州） 25万
# 七品 45两 45斛 1200两（知县） 23万
# 八品 40两 40斛 2万1千
# 九品 33两1.14钱 33斛1.14斗 1万8千
# 未入流 31两5钱 31斛5斗 1万1千

# %%
import pickle

# write a file
f = open("../data/pickles/all_important_inter2.pickle", "wb") # index_table, A, T, N, P, c, pos
# for obj in [index_table, A, T, N, P, mat_A, c, pos]:
pickle.dump(index_table, f, protocol=4)
pickle.dump(A, f, protocol=4)
pickle.dump(T, f, protocol=4)
pickle.dump(N, f, protocol=4)
pickle.dump(P, f, protocol=4)
# pickle.dump(mat_A, f, protocol=4)
pickle.dump(c, f, protocol=4)
pickle.dump(pos, f, protocol=4)

f.close()

# %%
import pickle
# for loading the objects
f = open("../data/pickles/all_important_inter2.pickle", "rb")
index_table = pickle.load(f)
A = pickle.load(f)
T = pickle.load(f)
N = pickle.load(f)
P = pickle.load(f)
# mat_A = pickle.load(f, protocol=4)
c = pickle.load(f)
pos = pickle.load(f)
    
f.close()

# %% [markdown]
# # Final calculation of value

# %%
for i in range(len(pos)):
    mat_A[i, i]= 1-mat_A[i,i]

# %%
x=np.linalg.solve(mat_A, c) # unsolvable on PC, moved to server

# %%
import pickle
f = open("../data/pickles/x2_alpha08.pickle", "rb") 
x=pickle.load(f)
f.close()

# %%
x[:50]
# Out:
# array([ 7239.17762467,  5176.54153009,  -187.51028028,  6319.04355415,
#         7922.87750181, 11803.27906528,  6557.37660707, 16000.        ,
#         7220.15670947,  9099.80397756,  8625.24489952,  9218.44373824,
#         8476.94520089,  9403.81835876,  9218.44373824,  8476.94520089,
#        14182.58941456, 14032.64410467, 14460.43499082,  9500.        ,
#        11498.69533951,   242.2654104 ,  6316.2983748 ,  2400.        ,
#         1139.95607592,  -407.3218546 ,  -876.65053248, 14662.26040328,
#          719.99389346,  1384.17143972,  1754.97068785,  -203.9765712 ,
#         1222.7487731 , -2681.37456525, 10385.91115847,  4356.34955312,
#         1200.        ,   749.04987061,  9411.72322813, 19312.46668352,
#         2489.67163539, -1847.64708141, 10463.48984051,  6943.89679621,
#         3195.12895712,  6527.57456465, 26534.19292695,  1325.85748853,
#        -4088.43190532,  1825.        ])

# %%
c[:50]
# Out:
# array([ 6000.,  6000.,  1250.,  2400.,  3700., 16000., 16000., 16000.,
#        14500., 16000., 16000., 16000., 16000., 16000., 16000., 16000.,
#        13000., 13000., 14500.,  9500., 13000.,  1250.,  2400.,  2400.,
#         1000.,  1000.,  1000.,  3700.,  1000.,  1250.,  1200.,  1200.,
#         1200.,  2400.,  2400.,  1250.,  1200.,  1000.,  2400., 14500.,
#         1200.,  1200., 13000.,  9500.,  9500., 13000., 14500.,  1000.,
#         1825.,  1825.])

# %%
assert(len(pos)==len(c))
potential=x-c

# %%
counts=[]
vc=ppry[['diqu','jigou_1','jigou_2','jigou_3','core_guanzhi']].apply(combine, axis=1).value_counts()

# %%
iv_pinji={}
for key, value in pinji_iv.items():
    iv_pinji[value]=key
for i in pos:
    counts.append(vc[i])
    result=[(x,y,z,iv_pinji[c[index_table[x]]])for x,y,z in list(zip(pos, potential, counts))]
result=pd.DataFrame(result, columns=['position', 'potential', 'occurrence', 'pinji'])
#Save result to .csv
f=open('../data/pickles/result2.pickle', 'wb')
pickle.dump(result, f)
f.close()

# %%
result=None
with open('../data/pickles/result2.pickle', 'rb') as f:
    result=pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-12-82a116017043> in <module>()
#       1 result=None
#       2 with open('../data/pickles/result2.pickle', 'rb') as f:
# ----> 3     result=pickle.load(f)
#
# EOFError: Ran out of input

# %%
# for pj in np.arange(3,10.5,0.5):
#     query_result=result[(result['occurrence']>10) & (result['pinji']==pj) ].sort_values(by='potential', ascending = False)
#     query_result.to_csv('../data/result_csv2/pinji_{}.csv'.format(pj), encoding="utf_8_sig", index=False)
result[result['occurrence']>10].sort_values(by='potential', ascending = False).to_csv('../data/result_csv2/all.csv'.format(pj), encoding="utf_8_sig", index=False)

# %%
result.head()
# Out:
#             position    potential  occurrence  pinji
# 0    京師_宗人府_不详_不详_府丞  1239.177625           3    3.0
# 1  京師_宗人府衙門_不详_不详_府丞  -823.458470          92    3.0
# 2   京師_宗人府_經歷司_不详_主事 -1437.510280           6    6.0
# 3  京師_刑部衙門_督捕司_不详_郎中  3919.043554         167    5.0
# 4  京師_鴻臚寺衙門_不详_不详_少卿  4222.877502           3    4.0

# %% [markdown]
# Visualization

# %%
filtered_result=result[result['occurrence']>10].sort_values(by='potential', ascending = False)
filtered_result['potential'].hist(figsize=(15,8), bins=100)

# %%
plt.figure(figsize=(15,8))
plt.plot(np.arange(filtered_result.shape[0]), filtered_result['potential'])
plt.title('potential distribution\n', size=40)
plt.ylabel('potential', size=30)
# Out:
# Text(0,0.5,'potential')

# %%
plt.figure(figsize=(15,8))
plt.plot(np.arange(1, filtered_result.shape[0]+1), filtered_result['pinji'])
plt.title('pinji distribution\n', size=40)
plt.ylabel('pinji', size=30)
plt.xlabel('index ranked by potential,\n i.e. 1-highest potential,\n 15701-lowest potential', size=20)
# Out:
# Text(0.5,0,'index ranked by potential,\n i.e. 1-highest potential,\n 15701-lowest potential')

# %% [markdown]
# ### The best potential's are high-ranked, the worst too.

# %%
print(('position', 'potential score', 'number of people'))
count=0
for r in sorted_result:
    if r[2]>10:
        print(r)
        count+=1
    if count>100:
        break

# %%
总兵官，知府/同知/知州，副都御史

# %%
count=0
year=0
for id_, subtable in tqdm(ppry.groupby('unique_id')):
    count+=1
    year+=(subtable['year'].max()-subtable['year'].min())

# %%
np.array(potential).mean()

# %% [markdown]
# # Regional Analysis

# %%
ppry['position'] = ppry[['diqu','jigou_1','jigou_2','jigou_3','core_guanzhi']].apply(combine, axis=1)

# %%
ppry.head(20)
# Out:
#            unique_id diqu jigou_1 jigou_2 jigou_3      core_guanzhi  \
# 181812  1.760400e+11   京師     宗人府     NaN     NaN                府丞
# 181813  1.760400e+11   京師     宗人府     NaN     NaN                府丞
# 181814  1.760400e+11   京師   宗人府衙門     NaN     NaN                府丞
# 181815  1.760400e+11   京師     宗人府     NaN     NaN                府丞
# 181838  1.760400e+11   京師     宗人府     經歷司     NaN                主事
# 181839  1.760400e+11   京師     宗人府     經歷司     NaN                主事
# 181840  1.760400e+11   京師     宗人府     經歷司     NaN                主事
# 181841  1.760400e+11   京師     宗人府     經歷司     NaN                主事
# 181842  1.760400e+11   京師    刑部衙門     督捕司     NaN                郎中
# 181843  1.760400e+11   京師    刑部衙門     督捕司     NaN                郎中
# 181844  1.760400e+11   京師   鴻臚寺衙門     NaN     NaN                少卿
# 182009  1.760400e+11   京師      工部     NaN     NaN    經筳講官太子太傅文淵閣大學士
# 182011  1.760400e+11   京師      內閣     NaN     NaN    經筵講官太子太傅文淵閣大學士
# 182012  1.760400e+11   京師      工部     NaN     NaN    經筳講官太子太傅文淵閣大學士
# 182014  1.760400e+11   京師      戶部     NaN     NaN  經筳講官起居註太子少保?閣大學士
# 182016  1.760400e+11   京師      內閣     NaN     NaN     經筵講官太子太保協辦大學士
# 182017  1.760400e+11   京師      吏部     NaN     NaN     經筳講官太子太保協辦大學士
# 182018  1.760400e+11   京師      兵部     NaN     NaN     經筳講官太子太保東閣大學士
# 182019  1.760400e+11   京師      內閣     NaN     NaN     經筳講官太子太保東閣大學士
# 182020  1.760400e+11   京師    兵部衙門     NaN     NaN  經筵講官起居註太子太保東閣大學士
#
#         pinji_detailed_numeric     year                        position
# 181812                     3.0  1760.75                 京師_宗人府_不详_不详_府丞
# 181813                     3.0  1761.50                 京師_宗人府_不详_不详_府丞
# 181814                     3.0  1765.00               京師_宗人府衙門_不详_不详_府丞
# 181815                     3.0  1765.75                 京師_宗人府_不详_不详_府丞
# 181838                     6.0  1760.75                京師_宗人府_經歷司_不详_主事
# 181839                     6.0  1761.50                京師_宗人府_經歷司_不详_主事
# 181840                     6.0  1760.75                京師_宗人府_經歷司_不详_主事
# 181841                     6.0  1761.50                京師_宗人府_經歷司_不详_主事
# 181842                     5.0  1765.00               京師_刑部衙門_督捕司_不详_郎中
# 181843                     5.0  1765.75               京師_刑部衙門_督捕司_不详_郎中
# 181844                     4.0  1777.50               京師_鴻臚寺衙門_不详_不详_少卿
# 182009                     1.0  1760.75      京師_工部_不详_不详_經筳講官太子太傅文淵閣大學士
# 182011                     1.0  1761.50      京師_內閣_不详_不详_經筵講官太子太傅文淵閣大學士
# 182012                     1.0  1761.50      京師_工部_不详_不详_經筳講官太子太傅文淵閣大學士
# 182014                     1.0  1760.75    京師_戶部_不详_不详_經筳講官起居註太子少保?閣大學士
# 182016                     1.5  1760.75       京師_內閣_不详_不详_經筵講官太子太保協辦大學士
# 182017                     1.0  1760.75       京師_吏部_不详_不详_經筳講官太子太保協辦大學士
# 182018                     1.0  1761.50       京師_兵部_不详_不详_經筳講官太子太保東閣大學士
# 182019                     1.0  1761.50       京師_內閣_不详_不详_經筳講官太子太保東閣大學士
# 182020                     1.0  1765.00  京師_兵部衙門_不详_不详_經筵講官起居註太子太保東閣大學士

# %%
ppry_with_potentials=ppry.join(result.set_index('position'), on='position', lsuffix='_original', rsuffix='_result')

# %%
ppry.head()
# Out:
#            unique_id diqu jigou_1 jigou_2 jigou_3 core_guanzhi  \
# 181812  1.760400e+11   京師     宗人府     NaN     NaN           府丞
# 181813  1.760400e+11   京師     宗人府     NaN     NaN           府丞
# 181814  1.760400e+11   京師   宗人府衙門     NaN     NaN           府丞
# 181815  1.760400e+11   京師     宗人府     NaN     NaN           府丞
# 181838  1.760400e+11   京師     宗人府     經歷司     NaN           主事
#
#         pinji_detailed_numeric     year           position
# 181812                     3.0  1760.75    京師_宗人府_不详_不详_府丞
# 181813                     3.0  1761.50    京師_宗人府_不详_不详_府丞
# 181814                     3.0  1765.00  京師_宗人府衙門_不详_不详_府丞
# 181815                     3.0  1765.75    京師_宗人府_不详_不详_府丞
# 181838                     6.0  1760.75   京師_宗人府_經歷司_不详_主事

# %%
result.head()
# Out:
#             position    potential  occurrence  pinji
# 0    京師_宗人府_不详_不详_府丞  1239.177625           3    3.0
# 1  京師_宗人府衙門_不详_不详_府丞  -823.458470          92    3.0
# 2   京師_宗人府_經歷司_不详_主事 -1437.510280           6    6.0
# 3  京師_刑部衙門_督捕司_不详_郎中  3919.043554         167    5.0
# 4  京師_鴻臚寺衙門_不详_不详_少卿  4222.877502           3    4.0

# %%
ppry_with_potentials.head()
# Out:
#            unique_id diqu jigou_1 jigou_2 jigou_3 core_guanzhi  \
# 181812  1.760400e+11   京師     宗人府     NaN     NaN           府丞
# 181813  1.760400e+11   京師     宗人府     NaN     NaN           府丞
# 181814  1.760400e+11   京師   宗人府衙門     NaN     NaN           府丞
# 181815  1.760400e+11   京師     宗人府     NaN     NaN           府丞
# 181838  1.760400e+11   京師     宗人府     經歷司     NaN           主事
#
#         pinji_detailed_numeric     year           position    potential  \
# 181812                     3.0  1760.75    京師_宗人府_不详_不详_府丞  1239.177625
# 181813                     3.0  1761.50    京師_宗人府_不详_不详_府丞  1239.177625
# 181814                     3.0  1765.00  京師_宗人府衙門_不详_不详_府丞  -823.458470
# 181815                     3.0  1765.75    京師_宗人府_不详_不详_府丞  1239.177625
# 181838                     6.0  1760.75   京師_宗人府_經歷司_不详_主事 -1437.510280
#
#         occurrence  pinji
# 181812           3    3.0
# 181813           3    3.0
# 181814          92    3.0
# 181815           3    3.0
# 181838           6    6.0

# %%
regional_potentials=ppry_with_potentials[['diqu', 'potential']].groupby('diqu').agg(['mean', 'count'])['potential'].sort_values(by='mean', ascending=False)
regional_potentials[regional_potentials['count']>10]
# Out:
#                        mean   count
# diqu
# 甘肅新將            4491.114865    4334
# 吉林              2967.374823    1028
# 黑龍江             2670.072913     545
# 奉天              2256.355298    2637
# 山東              2034.968104  119162
# 雲南              1965.964707   71818
# 甘肅              1903.782246   47452
# 貴州              1830.842451   52302
# 京師              1561.083229  254635
# 湖北              1554.743083   80257
# 吉林甯古塔城          1544.881644     514
# 福建              1544.225557   75139
# 浙江              1460.082141   93828
# 廣西              1442.114766   74143
# 盛京              1392.600336   11233
# 湖南              1387.071296   76198
# 陝西              1374.516668   71219
# 廣東              1350.884772  105507
# 四川              1289.686758  112147
# 江南              1267.590742   70804
# 江西              1252.774188  100041
# 安徽              1187.733445   64210
# 河南              1135.093692  102662
# 直隸              1112.008553  142402
# 山西              1087.635565   87231
# 福建臺灣             863.434305     850
# 江蘇               541.105366   35562
# 黑龍江城              65.708096      41
# 湖廣              -417.876712     445
# 臺灣             -1681.895707     342
# 光緒十八年壬辰科會試試差人員 -3171.730816      27

# %%
import matplotlib as mpl
plt.style.use('seaborn-whitegrid')
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(16,9))
plt.bar(np.arange(regional_potentials.shape[0]), regional_potentials['mean'])
_=plt.xticks(np.arange(regional_potentials.shape[0]), regional_potentials.index.tolist(), rotation=40, size=13)
_=plt.ylim(-4000, 5000)
plt.ylabel('potential', size=15,rotation=0)
# Out:
# Text(0,0.5,'potential')

# %%
ppry_with_potentials[['diqu', 'jigou_1', 'potential']].groupby(['diqu', 'jigou_1']).agg(['mean', 'count'])['potential'].sort_values(by='mean', ascending=False)
# Out:
#                                  mean  count
# diqu           jigou_1
# 廣西             布政司       52000.003874      2
# 浙江             布政司       52000.003874      2
# 貴州             布政司       28500.002123      4
# 雲南             布政司       28500.002123      4
# 廣東             布政司       28500.002123      4
# 甘肅新將           布政司       28500.002123      4
# 四川             布政司       28500.002123      4
# 陝西             布政司       28450.002120      4
# 江南             江甯布政司     28450.002120      4
# 安徽             海軍提標      27086.156659      5
# 江西             布政司       26000.001937      4
# 湖北             提學司       24000.001788      2
# 四川             提學司       24000.001788      2
# 直隸             布政司       18966.668080      6
# 四川             鹽務        14800.001103      2
# 廣東             提學司衙門     14618.851236     19
# 奉天             鹽運司衙門     13996.237562      4
# 陝西             提學司衙門     13183.067616     19
# 湖南             鳯凰直隸廳     12972.199690   1151
#                布政司衙門     12972.090009    299
# 福建             提學司衙門     11957.303884     19
# 廣西             提學司衙門     11957.303884     19
# 甘肅新將           鎮西直隸廳     11933.671433    335
# 浙江             提學司衙門     11901.746621     19
# 湖北             布政司衙門     11853.346972    305
# 直隸             提學司衙門     11830.172746     19
# 四川             提學司衙門     11689.740170     19
# 江蘇             新設長江水師    11333.730781     90
# 京師             資政院衙門     11333.334178      6
# 湖南             提法司衙門     11100.000827      4
# ...                               ...    ...
# 陝西             提法司衙門     -4171.663720      3
# 江蘇             江寧布政司衙門   -4254.833116     31
# 江南             江蘇???院    -4494.026204      2
# 甘肅             綏德直隸州     -4551.355836     45
# 奉天             黑龍江城      -4623.354974      9
# 京師             憲政編察館     -4668.638768      4
#                會議政務處     -4673.680602     20
#                政務處       -5005.586742    179
# 甘肅新將           防戍        -5043.520929      2
# 福建             福建省       -5129.678613      4
# 甘肅             伊犁府       -5830.498202      5
# 江蘇             江蘇按察使司衙門  -5937.795273      2
# 吉林             蒙江州       -6369.815182      1
# 江南             江南省       -6614.558342      9
# 京師             總兵處       -6652.305663     12
# 雲南             鎮?撫彞直隸廳   -6829.973011      1
#                鹽務        -6872.864412      1
# 臺灣             巡撫部院      -7364.365075     25
#                布政司衙門     -7704.097304     10
# 京師             內閣衙門大學士   -7783.133749      4
# 吉林             呢嗎口       -8376.743254      1
# 京師             弼德院衙門     -9641.587311      3
# 光緒十八年壬辰科會試試差人員 天總裁      -10716.878605      1
#                副總裁      -11051.345871      2
# 江蘇             江南省      -11568.348165      1
# 503            甯波府      -12800.870200      1
# 安徽             安徽省      -14338.458673      4
# 江南             江蘇巡撫部院   -14612.087331     14
# 京師             北洋海軍提標   -16457.259112      6
# 甘肅             新將       -23371.827965      9
#
# [1146 rows x 2 columns]

# %%
year_potentials

# %%
plt.figure(figsize=(16,10))
year_potentials=ppry_with_potentials[['year', 'potential']].groupby('year').agg(['mean', 'count'])['potential'].sort_values(by='mean', ascending=False)
year_potentials.reset_index(inplace=True)
year_potentials.sort_values('year', inplace=True)
ax1=plt.gca()
plt.ylabel('potential', size=20)
plt.xlabel('year', size=20)
plt.ylim(0,2750)
plt.title('potential-year over the country', size=30)
ax2=ax1.twinx()
ax2.bar(year_potentials['year'], year_potentials['count'], color='r', alpha=.3)
ax2.set_ylim(8000, 12000)
ax2.set_ylabel('#records', size=20)
ax1.plot(year_potentials['year'], year_potentials['mean'], '-o')

# %%
plt.figure(figsize=(16,10))
ppry_with_potentials_central=ppry_with_potentials[ppry_with_potentials['diqu']=='京師']
year_potentials=ppry_with_potentials_central[['year', 'potential']].groupby('year').agg(['mean', 'count'])['potential'].sort_values(by='mean', ascending=False)
year_potentials.reset_index(inplace=True)
year_potentials.sort_values('year', inplace=True)
ax1=plt.gca()
plt.ylabel('potential', size=20)
plt.xlabel('year', size=20)
# plt.ylim(-500,2750)
plt.title('potential-year in 京師', size=30)
ax2=ax1.twinx()
ax2.bar(year_potentials['year'], year_potentials['count'], color='r', alpha=.3)
# ax2.set_ylim(8000, 12000)
ax2.set_ylabel('#records', size=20)
ax1.plot(year_potentials['year'], year_potentials['mean'], '-o')
# plt.axvline(x=1895, color='y', linestyle='--')
# plt.text(1893, -100, '1895')
# Out:
# Text(1893,-100,'1882')

# %%
plt.figure(figsize=(16,10))
ppry_with_potentials_central=ppry_with_potentials[ppry_with_potentials['diqu']=='廣東']
year_potentials=ppry_with_potentials_central[['year', 'potential']].groupby('year').agg(['mean', 'count'])['potential'].sort_values(by='mean', ascending=False)
year_potentials.reset_index(inplace=True)
year_potentials.sort_values('year', inplace=True)
ax1=plt.gca()
plt.ylabel('potential', size=20)
plt.xlabel('year', size=20)
# plt.ylim(-500,2750)
plt.title('potential-year in 廣東', size=30)
# ax2=ax1.twinx()
# ax2.bar(year_potentials['year'], year_potentials['count'], color='r', alpha=.3)
# ax2.set_ylabel('#records', size=20)
ax1.plot(year_potentials['year'], year_potentials['mean'], '-o')
# plt.axvline(x=1895, color='y', linestyle='--')
# plt.text(1893, -100, '1895')

# %% [markdown]
# # For Visualization

# %% [markdown]
# ## 1. For the whole network

# %%
import networkx as nx
def flatten_dict(d):
    res=[]
    for key, item in tqdm(d.items()):
        res.append((*key, item))
    return res
g=nx.DiGraph()
g.add_weighted_edges_from(flatten_dict(flow_count))

# %%
(len(list(g.nodes)), len(list(g.edges)))

# %%
nx.write_gexf(g, r'../data/gephi/pos_network.gexf')

# %% [markdown]
# ## 2. For subgraph

# %%
def create_subgraph(start_pos, graph, pos, depth=5):
    # do a BDS, start_pos IS AN INDEX! NOT A NAME!
    subgraph=[] # used to store edges
    this_layer=[] # store the nodes to be traced further
    next_layer=[start_pos]
    past={start_pos:1} # store every nodes seen before
    for layer in range(depth):
        this_layer=next_layer.copy()
        next_layer=[]
        if len(this_layer)==0:
            break
        for pos1 in this_layer:
            row=graph.get(pos1)
            if row:
                for pos2, count in row.items():
                    subgraph.append((pos[pos1], pos[pos2], count))
                    if pos2 not in past:
                        past[pos2]=1
                        next_layer.append(pos2)
                        
                    
                
                
                
    return subgraph

# %%
import networkx as nx
position_name='江甯府 南捕通判'
r=create_subgraph(index_table[position_name], N, pos, depth=3)
print(len(r))
print(sorted(r))
subg=nx.DiGraph()
subg.add_weighted_edges_from(r)
nx.write_gexf(subg, r'../data/gephi/subgraph_{}.gexf'.format(position_name))

# %% [markdown]
# ## Micro Measurement: in unit of shortest segment with length 1

# %%
# %%script false
# pos_score={} #{pos->[promotions, count]}
# duplicate_count=0
# for id_, subtable in tqdm(ppry.groupby('unique_id')):
#
#     pre_year=None
#     pre_pinji=None
#     pre_pos=None
#     for index, row in subtable.sort_values('year').iterrows():
# #         print(row)
#         if not pre_year:
#             pre_year=row['year']
#             pre_pinji=row['pinji_detailed_numeric']
#             pre_pos=(row['jigou_1'], row['guanzhi'])
#         else:
#             promotion=-(row['pinji_detailed_numeric']-pre_pinji) # if get promoted, the numeric value of rank actually decreases
#             time=row['year']-pre_year
#             if time==0:
#                 duplicate_count+=1
#                 #update tracking variables
#                 pre_year=row['year']
#                 pre_pinji=row['pinji_detailed_numeric']
#                 continue
#
#             # update pos_score for pre_pose
#             if pre_pos in pos_score:
#                 pos_score[pre_pos][0]+=(promotion/time)
#                 pos_score[pre_pos][1]+=1
#             else:
#                 pos_score[pre_pos]=[promotion/time, 1]
#
#             #update tracking variables
#             pre_year=row['year']
#             pre_pinji=row['pinji_detailed_numeric']
#             pre_pos=(row['jigou_1'], row['guanzhi'])

# %%
print(duplicate_count)

# %%
pos_score_micro=pos_score
pos_normscore={}
curoff_occurences=100
for key, value in pos_score_micro.items():
    if value[1]<curoff_occurences: # MUST do this filteration to remove noise: remove occurences < 5
        continue
    pos_normscore[key]=[value[0]/value[1], value[1]]
pos_ranking_micro=sorted(list(pos_normscore.items()), key=lambda x: -x[1][0])
from pprint import pprint
pprint(pos_ranking_micro[:30])

# %% [markdown]
# Note: a minor problem remains unsolved: duplicate record a specific person in a specific year

# %% [markdown]
# ## Local Measurement: in unit of a person

# %%
import random

pos_score={} #{pos->[promotions, count]}
duplicate_count2=0
for id_, subtable in tqdm(ppry.groupby('unique_id')):
    # sample a subset to reduce size
#     if random.uniform(0, 1)>0.1:
#         continue
        
        
    st=list(subtable.sort_values('year').T.to_dict().values())
    length=len(st)
    for idx, row1 in enumerate(st):
        if idx>=length-1:
            break
            
        #start calculating for a specific position in one person's career
        pos=(row1['jigou_1'], row1['guanzhi'])
        score=0
        count=0
        cur_pinji=row1['pinji_detailed_numeric']
        cur_year=row1['year']
        for row2 in st[idx+1:]:
            promotion=-(row2['pinji_detailed_numeric']-cur_pinji) # if get promoted, the numeric value of rank actually decreases
            time=row2['year']-cur_year
            if time==0:
                continue
            score+=promotion/time
            count+=1
            
        if count==0:
            duplicate_count2+=1
            continue
        # update pos_score
        if pos in pos_score:
            pos_score[pos][0]+=(score/count)
            pos_score[pos][1]+=1
        else:
            pos_score[pos]=[score/count, 1]

# %%
pos_score_local=pos_score
pos_normscore={}
curoff_occurences=100
for key, value in pos_score_local.items():
    if value[1]<curoff_occurences: # MUST do this filteration to remove noise: remove occurences < 5
        continue
    pos_normscore[key]=[value[0]/value[1], value[1]]
pos_ranking_local=sorted(list(pos_normscore.items()), key=lambda x: -x[1][0])
from pprint import pprint
pprint(pos_ranking_local[:30])

# %%
count=0
for id_, subtable in tqdm(ppry.groupby('unique_id')):
    if '小京官' in subtable['guanzhi'].unique() and '農工商部衙門' in subtable['jigou_1'].unique():
        print(subtable.sort_values(by='year')[['jigou_1','guanzhi' ,'pinji_detailed_numeric', 'year']])
        count+=1
#     if count>3:
#         break

# %%
np.__version__
# Out:
# '1.14.2'
